# %%
# Standard 
import numpy as np 
import pandas as pd
from numpy.random import randn

# %%
#stats
from scipy import stats

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# %matplotlib inline

# %%
url ='https://sv.wikipedia.org/wiki/Histogram'

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 1.,  6.,  5.,  6., 20., 16., 12., 16., 13.,  5.]),
#  array([-2.85521578, -2.36113302, -1.86705026, -1.3729675 , -0.87888474,
#         -0.38480197,  0.10928079,  0.60336355,  1.09744631,  1.59152907,
#          2.08561183]),
#  <BarContainer object of 10 artists>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color ='indianred')
# Out:
# (array([ 1.,  3., 14., 10., 19., 16.,  9.,  6.,  0.,  2.]),
#  array([-2.3564931 , -1.87296679, -1.38944049, -0.90591418, -0.42238787,
#          0.06113843,  0.54466474,  1.02819105,  1.51171736,  1.99524366,
#          2.47876997]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,alpha=0.5,bins=20)
# Out:
# (array([ 1.,  0.,  1.,  2.,  5.,  9.,  6.,  4.,  9., 10.,  7.,  9.,  3.,
#          6.,  3.,  3.,  0.,  0.,  1.,  1.]),
#  array([-2.3564931 , -2.11472995, -1.87296679, -1.63120364, -1.38944049,
#         -1.14767733, -0.90591418, -0.66415103, -0.42238787, -0.18062472,
#          0.06113843,  0.30290159,  0.54466474,  0.7864279 ,  1.02819105,
#          1.2699542 ,  1.51171736,  1.75348051,  1.99524366,  2.23700682,
#          2.47876997]),
#  <BarContainer object of 20 artists>)

# %%
data1=randn(1000)
data2=randn(1000)

# %%
sns.jointplot(data1,data2)
# Out:
# /Users/markella/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data1,data2,kind ='hex')
# Out:
# /Users/markella/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np 
import pandas as pd 
from pandas import Series,DataFrame

# %%
import  webbrowser 
website='https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame =pd.read_clipboard()

# %%
nfl_frame
# Out:
#                          Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay       Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys       932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens        402    226  175    1   0.563  1996.000   AFC  North
# 4 Chicago   Bears       1,420    778  600   42   0.563  1920.000   NFC  North
# 5 New       England  Patriots    934  520  405   9.000     0.562  1960    AFC
#
#                     Division
# 1 Green     Bay        North
# 2 Dallas    Cowboys     None
# 3 Baltimore Ravens      None
# 4 Chicago   Bears       None
# 5 New       England     East

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'Season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame['Season']
# Out:
# 1  Green      Bay          NFC
# 2  Dallas     Cowboys     East
# 3  Baltimore  Ravens     North
# 4  Chicago    Bears      North
# 5  New        England      AFC
# Name: Season, dtype: object

# %%
DataFrame(nfl_frame,columns=['Team','GP','Season'])
# Out:
#                       Team   GP Season
# 1 Green     Bay      1,386  770    NFC
# 2 Dallas    Cowboys    527  399   East
# 3 Baltimore Ravens     226  175  North
# 4 Chicago   Bears      778  600  North
# 5 New       England    934  520    AFC

# %%
DataFrame(nfl_frame,columns=['Team','GP','Season','RandomRequestColumn'])
# Out:
#                       Team   GP Season  RandomRequestColumn
# 1 Green     Bay      1,386  770    NFC                  NaN
# 2 Dallas    Cowboys    527  399   East                  NaN
# 3 Baltimore Ravens     226  175  North                  NaN
# 4 Chicago   Bears      778  600  North                  NaN
# 5 New       England    934  520    AFC                  NaN

# %%
nfl_frame.head(3)
# Out:
#                         Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay      Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys      932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens       402    226  175    1   0.563  1996.000   AFC  North
#
#                     Division
# 1 Green     Bay        North
# 2 Dallas    Cowboys     None
# 3 Baltimore Ravens      None

# %%
nfl_frame.tail(2)
# Out:
#                        Rank Team   GP  Won   Lost      Tied  Pct. Season  \
# 4 Chicago Bears       1,420  778  600   42  0.563  1920.000   NFC  North
# 5 New     England  Patriots  934  520  405  9.000     0.562  1960    AFC
#
#                   Division
# 4 Chicago Bears       None
# 5 New     England     East

# %%
nfl_frame.index[3]
# Out:
# (4, 'Chicago', 'Bears')

# %%
nfl_frame['Stadium']="LV"

# %%
nfl_frame
# Out:
#                          Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay       Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys       932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens        402    226  175    1   0.563  1996.000   AFC  North
# 4 Chicago   Bears       1,420    778  600   42   0.563  1920.000   NFC  North
# 5 New       England  Patriots    934  520  405   9.000     0.562  1960    AFC
#
#                     Division Stadium
# 1 Green     Bay        North      LV
# 2 Dallas    Cowboys     None      LV
# 3 Baltimore Ravens      None      LV
# 4 Chicago   Bears       None      LV
# 5 New       England     East      LV

# %%
nfl_frame['Stadium']=np.arange(5)

# %%
nfl_frame
# Out:
#                          Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay       Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys       932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens        402    226  175    1   0.563  1996.000   AFC  North
# 4 Chicago   Bears       1,420    778  600   42   0.563  1920.000   NFC  North
# 5 New       England  Patriots    934  520  405   9.000     0.562  1960    AFC
#
#                     Division  Stadium
# 1 Green     Bay        North        0
# 2 Dallas    Cowboys     None        1
# 3 Baltimore Ravens      None        2
# 4 Chicago   Bears       None        3
# 5 New       England     East        4

# %%
stadiums =Series(["LV","ATT"],index=[4,0])

# %%
stadiums
# Out:
# 4     LV
# 0    ATT
# dtype: object

# %%
nfl_frame['Stadium']= stadiums

# %%
nfl_frame
# Out:
#                          Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay       Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys       932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens        402    226  175    1   0.563  1996.000   AFC  North
# 4 Chicago   Bears       1,420    778  600   42   0.563  1920.000   NFC  North
# 5 New       England  Patriots    934  520  405   9.000     0.562  1960    AFC
#
#                     Division Stadium
# 1 Green     Bay        North     NaN
# 2 Dallas    Cowboys     None     NaN
# 3 Baltimore Ravens      None     NaN
# 4 Chicago   Bears       None     NaN
# 5 New       England     East     NaN

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#                          Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay       Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys       932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens        402    226  175    1   0.563  1996.000   AFC  North
# 4 Chicago   Bears       1,420    778  600   42   0.563  1920.000   NFC  North
# 5 New       England  Patriots    934  520  405   9.000     0.562  1960    AFC
#
#                     Division
# 1 Green     Bay        North
# 2 Dallas    Cowboys     None
# 3 Baltimore Ravens      None
# 4 Chicago   Bears       None
# 5 New       England     East

# %%
data={'City':['SF','LA','NY'],'Population':[444444444444,23443435454343,87854545454]}

# %%
city_frame=DataFrame(data)

city_frame
# Out:
#   City      Population
# 0   SF    444444444444
# 1   LA  23443435454343
# 2   NY     87854545454
